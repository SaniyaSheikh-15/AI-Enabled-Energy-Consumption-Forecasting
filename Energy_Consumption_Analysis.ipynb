# %% [markdown]
# # Energy Consumption Analysis (Multi-household)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data/energy_multi_household.csv', parse_dates=['datetime'])
df.groupby('household_id')['energy_kwh'].mean().sort_values().plot(kind='bar', title='Avg energy per household')
plt.show()
